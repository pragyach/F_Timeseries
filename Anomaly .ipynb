# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dframe=pd.read_csv('F:/basic-predictions-bounds4.csv')

# %%
dframe.head()
# Out:
#                   time  docker_cpu_system  predict_upper  predict_lower  \
# 0  2018-05-16T10:30:00           3.476838      19.607810       3.476838
# 1  2018-05-16T10:30:00          14.297699      19.607810       3.476838
# 2  2018-05-16T10:30:00           3.050016      19.607810       3.476838
# 3  2018-05-16T10:30:00           0.411599      15.259491       3.476838
# 4  2018-05-16T10:30:00           1.041534      15.259491       3.050016
#
#    isAnomaly
# 0          0
# 1          0
# 2          1
# 3          1
# 4          1

# %%
fig, ax1 = plt.subplots(1, 1,figsize=(15, 8))
ax1.plot(dframe.docker_cpu_system,label=dframe)
ax1.fill_between(dframe.predict_upper,dframe.predict_lower,color='grey',alpha=0.3,label='1Sigma')
